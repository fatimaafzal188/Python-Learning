# %% [markdown]
# # Steps

# %% [markdown]
# 1.gathering the data
# 2. acessing the data
# 3. cleaning the data
#    1. dealing with missing values
#    2. correcting errors in data
#      1. outliers removal
#        1.visualization
#        2. IQR method
#        3. z-score
#    3. dropping duplicates.
