# %%
name = input("Enter your name: ")

# %% [markdown]
# * using input function to get a name *

# %%
print('hello', name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print('hello',fatima)
#
# NameError: name 'fatima' is not defined

# %% [markdown]
# **printing results.**

# %%
fruit_basket=('mangoes','oranges','pear')

# %%
fruit_basket
# Out:
# ('mangoes', 'oranges', 'pear')
